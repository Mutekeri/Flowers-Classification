# %%
from datetime import datetime
import hashlib
import os
import os.path
import random
import re
import sys
import tarfile

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.contrib.quantize.python import quant_ops
from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

# %% [markdown]
# ## Module variable

# %%
MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING = 10
MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING = 100

MIN_NUM_IMAGES_REQUIRED_FOR_TESTING = 3

MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

# path to folders of labeled images
TRAINING_IMAGES_DIR = os.getcwd() + '/training_images'

TEST_IMAGES_DIR = os.getcwd() + "/test_images/"

# where to save the trained graph
OUTPUT_GRAPH = os.getcwd() + '/' + 'retrained_graph.pb'

# where to save the intermediate graphs
INTERMEDIATE_OUTPUT_GRAPHS_DIR = os.getcwd() + '/intermediate_graph'

# how many steps to store intermediate graph, if "0" then will not store
INTERMEDIATE_STORE_FREQUENCY = 0

# where to save the trained graph's labels
OUTPUT_LABELS = os.getcwd() + '/' + 'retrained_labels.txt'

# where to save summary logs for TensorBoard
TENSORBOARD_DIR = os.getcwd() + '/' + 'tensorboard_logs'

# how many training steps to run before ending
# NOTE: original Google default is 4000, use 4000 (or possibly higher) for production grade results
HOW_MANY_TRAINING_STEPS=500

# how large a learning rate to use when training
LEARNING_RATE = 0.01

# what percentage of images to use as a test set
TESTING_PERCENTAGE = 10

# what percentage of images to use as a validation set
VALIDATION_PERCENTAGE = 10

# how often to evaluate the training results
EVAL_STEP_INTERVAL = 10

# how many images to train on at a time
TRAIN_BATCH_SIZE = 100

# How many images to test on. This test set is only used once, to evaluate the final accuracy of the model after
# training completes.  A value of -1 causes the entire test set to be used, which leads to more stable results across runs.
TEST_BATCH_SIZE = -1

# How many images to use in an evaluation batch. This validation set is used much more often than the test set, and is an early indicator of how
# accurate the model is during training. A value of -1 causes the entire validation set to be used, which leads to
# more stable results across training iterations, but may be slower on large training sets.
VALIDATION_BATCH_SIZE = 100

# whether to print out a list of all misclassified test images
PRINT_MISCLASSIFIED_TEST_IMAGES = False

# Path to classify_image_graph_def.pb, imagenet_synset_to_human_label_map.txt, and imagenet_2012_challenge_label_map_proto.pbtxt
MODEL_DIR = os.getcwd() + "/" + "model"

# Path to cache bottleneck layer values as files
BOTTLENECK_DIR = os.getcwd() + '/' + 'bottleneck_data'

# the name of the output classification layer in the retrained graph
FINAL_TENSOR_NAME = 'final_result'

# whether to randomly flip half of the training images horizontally
FLIP_LEFT_RIGHT = False

# a percentage determining how much of a margin to randomly crop off the training images
RANDOM_CROP = 0

# a percentage determining how much to randomly scale up the size of the training images by
RANDOM_SCALE = 0

# a percentage determining how much to randomly multiply the training image input pixels up or down by
RANDOM_BRIGHTNESS = 0

# Which model architecture to use. 'inception_v3' is the most accurate, but also the slowest. For faster or smaller models, chose a MobileNet with
# the form 'mobilenet_<parameter size>_<input_size>[_quantized]'. For example, 'mobilenet_1.0_224' will pick a model that is 17 MB in size and takes
# 224 pixel input images, while 'mobilenet_0.25_128_quantized' will choose a much less accurate, but smaller and faster network that's 920 KB
# on disk and takes 128x128 images. See https://research.googleblog.com/2017/06/mobilenets-open-source-models-for.html for more information on Mobilenet.

# By default this script will use the high accuracy, but comparatively large and slow Inception v3 model architecture.
# It's recommended that you start with this to validate that you have gathered good training data, but if you want to deploy
# on resource-limited platforms, you can try the `--architecture` flag with a Mobilenet model. For example:

# example command to run floating-point version of mobilenet:
# ARCHITECTURE = 'mobilenet_1.0_224'

# example command to run quantized version of mobilenet:
# ARCHITECTURE = 'mobilenet_1.0_224_quantized'

# There are 32 different Mobilenet models to choose from, with a variety of file size and latency options. The first
# number can be '1.0', '0.75', '0.50', or '0.25' to control the size, and the second controls the input image size,
# either '224', '192', '160', or '128', with smaller sizes running faster.
# See https://research.googleblog.com/2017/06/mobilenets-open-source-models-for.html for more information on Mobilenet.
ARCHITECTURE = 'inception_v3'

# %%
def main():
    print("starting program . . .")
    # make sure the logging output is visible, see https://github.com/tensorflow/tensorflow/issues/3047
    tf.logging.set_verbosity(tf.logging.INFO)

    if not checkIfNecessaryPathsAndFilesExist():
        return
    # end if

    # prepare necessary directories that can be used during training
    prepare_file_system()

    # Gather information about the model architecture we'll be using.
    model_info = create_model_info(ARCHITECTURE)
    if not model_info:
        tf.logging.error('Did not recognize architecture flag')
        return -1
    # end if

    # download the model if necessary, then create the model graph
    print("downloading model (if necessary) . . .")
    downloadModelIfNotAlreadyPresent(model_info['data_url'])
    print("creating model graph . . .")
    graph, bottleneck_tensor, resized_image_tensor = (create_model_graph(model_info))

    # Look at the folder structure, and create lists of all the images.
    print("creating image lists . . .")
    image_lists = create_image_lists(TRAINING_IMAGES_DIR, TESTING_PERCENTAGE, VALIDATION_PERCENTAGE)
    class_count = len(image_lists.keys())
    if class_count == 0:
        tf.logging.error('No valid folders of images found at ' + TRAINING_IMAGES_DIR)
        return -1
    # end if
    if class_count == 1:
        tf.logging.error('Only one valid folder of images found at ' + TRAINING_IMAGES_DIR + ' - multiple classes are needed for classification.')
        return -1
    # end if

    # determinf if any of the distortion command line flags have been set
    doDistortImages = False
    if (FLIP_LEFT_RIGHT == True or RANDOM_CROP != 0 or RANDOM_SCALE != 0 or RANDOM_BRIGHTNESS != 0):
        doDistortImages = True
    # end if

    print("starting session . . .")
    with tf.Session(graph=graph) as sess:
        # Set up the image decoding sub-graph.
        print("performing jpeg decoding . . .")
        jpeg_data_tensor, decoded_image_tensor = add_jpeg_decoding( model_info['input_width'],
                                                                    model_info['input_height'],
                                                                    model_info['input_depth'],
                                                                    model_info['input_mean'],
                                                                    model_info['input_std'])
        print("caching bottlenecks . . .")
        distorted_jpeg_data_tensor = None
        distorted_image_tensor = None
        if doDistortImages:
            # We will be applying distortions, so setup the operations we'll need.
            (distorted_jpeg_data_tensor, distorted_image_tensor) = add_input_distortions(FLIP_LEFT_RIGHT, RANDOM_CROP, RANDOM_SCALE,
                                                                                         RANDOM_BRIGHTNESS, model_info['input_width'],
                                                                                         model_info['input_height'], model_info['input_depth'],
                                                                                         model_info['input_mean'], model_info['input_std'])
        else:
            # We'll make sure we've calculated the 'bottleneck' image summaries and
            # cached them on disk.
            cache_bottlenecks(sess, image_lists, TRAINING_IMAGES_DIR, BOTTLENECK_DIR, jpeg_data_tensor, decoded_image_tensor,
                              resized_image_tensor, bottleneck_tensor, ARCHITECTURE)
        # end if

        # Add the new layer that we'll be training.
        print("adding final training layer . . .")
        (train_step, cross_entropy, bottleneck_input, ground_truth_input, final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                                                                                                 FINAL_TENSOR_NAME,
                                                                                                                 bottleneck_tensor,
                                                                                                                 model_info['bottleneck_tensor_size'],
                                                                                                                 model_info['quantize_layer'])
        # Create the operations we need to evaluate the accuracy of our new layer.
        print("adding eval ops for final training layer . . .")
        evaluation_step, prediction = add_evaluation_step(final_tensor, ground_truth_input)

        # Merge all the summaries and write them out to the tensorboard_dir
        print("writing TensorBoard info . . .")
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(TENSORBOARD_DIR + '/train', sess.graph)
        validation_writer = tf.summary.FileWriter(TENSORBOARD_DIR + '/validation')

        # Set up all our weights to their initial default values.
        init = tf.global_variables_initializer()
        sess.run(init)

        # Run the training for as many cycles as requested on the command line.
        print("performing training . . .")
        for i in range(HOW_MANY_TRAINING_STEPS):
            # Get a batch of input bottleneck values, either calculated fresh every
            # time with distortions applied, or from the cache stored on disk.
            if doDistortImages:
                (train_bottlenecks, train_ground_truth) = get_random_distorted_bottlenecks(sess, image_lists, TRAIN_BATCH_SIZE, 'training',
                                                                                           TRAINING_IMAGES_DIR, distorted_jpeg_data_tensor,
                                                                                           distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
            else:
                (train_bottlenecks, train_ground_truth, _) = get_random_cached_bottlenecks(sess, image_lists, TRAIN_BATCH_SIZE, 'training',
                                                                                           BOTTLENECK_DIR, TRAINING_IMAGES_DIR, jpeg_data_tensor,
                                                                                           decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                                                                                           ARCHITECTURE)
            # end if

            # Feed the bottlenecks and ground truth into the graph, and run a training
            # step. Capture training summaries for TensorBoard with the `merged` op.
            train_summary, _ = sess.run([merged, train_step], feed_dict={bottleneck_input: train_bottlenecks, ground_truth_input: train_ground_truth})
            train_writer.add_summary(train_summary, i)

            # Every so often, print out how well the graph is training.
            is_last_step = (i + 1 == HOW_MANY_TRAINING_STEPS)
            if (i % EVAL_STEP_INTERVAL) == 0 or is_last_step:
                train_accuracy, cross_entropy_value = sess.run([evaluation_step, cross_entropy], feed_dict={bottleneck_input: train_bottlenecks, ground_truth_input: train_ground_truth})
                tf.logging.info('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i, train_accuracy * 100))
                tf.logging.info('%s: Step %d: Cross entropy = %f' % (datetime.now(), i, cross_entropy_value))
                validation_bottlenecks, validation_ground_truth, _ = (get_random_cached_bottlenecks(sess, image_lists, VALIDATION_BATCH_SIZE, 'validation',
                                                                                                    BOTTLENECK_DIR, TRAINING_IMAGES_DIR, jpeg_data_tensor,
                                                                                                    decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                                                                                                    ARCHITECTURE))
                # Run a validation step and capture training summaries for TensorBoard with the `merged` op.
                validation_summary, validation_accuracy = sess.run(
                    [merged, evaluation_step], feed_dict={bottleneck_input: validation_bottlenecks, ground_truth_input: validation_ground_truth})
                validation_writer.add_summary(validation_summary, i)
                tf.logging.info('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' % (datetime.now(), i, validation_accuracy * 100, len(validation_bottlenecks)))
            # end if

            # Store intermediate results
            intermediate_frequency = INTERMEDIATE_STORE_FREQUENCY

            if (intermediate_frequency > 0 and (i % intermediate_frequency == 0) and i > 0):
                intermediate_file_name = (INTERMEDIATE_OUTPUT_GRAPHS_DIR + 'intermediate_' + str(i) + '.pb')
                tf.logging.info('Save intermediate result to : ' + intermediate_file_name)
                save_graph_to_file(sess, graph, intermediate_file_name)
            # end if
        # end for

        # We've completed all our training, so run a final test evaluation on some new images we haven't used before
        print("running testing . . .")
        test_bottlenecks, test_ground_truth, test_filenames = (get_random_cached_bottlenecks(sess, image_lists, TEST_BATCH_SIZE, 'testing', BOTTLENECK_DIR,
                                                                                             TRAINING_IMAGES_DIR, jpeg_data_tensor, decoded_image_tensor, resized_image_tensor,
                                                                                             bottleneck_tensor, ARCHITECTURE))
        test_accuracy, predictions = sess.run([evaluation_step, prediction], feed_dict={bottleneck_input: test_bottlenecks, ground_truth_input: test_ground_truth})
        tf.logging.info('Final test accuracy = %.1f%% (N=%d)' % (test_accuracy * 100, len(test_bottlenecks)))

        if PRINT_MISCLASSIFIED_TEST_IMAGES:
            tf.logging.info('=== MISCLASSIFIED TEST IMAGES ===')
            for i, test_filename in enumerate(test_filenames):
                if predictions[i] != test_ground_truth[i]:
                    tf.logging.info('%70s  %s' % (test_filename, list(image_lists.keys())[predictions[i]]))
                # end if
            # end for
        # end if

        # write out the trained graph and labels with the weights stored as constants
        print("writing trained graph and labbels with weights")
        save_graph_to_file(sess, graph, OUTPUT_GRAPH)
        with gfile.FastGFile(OUTPUT_LABELS, 'w') as f:
            f.write('\n'.join(image_lists.keys()) + '\n')
        # end with

        print("done !!")
# end function

# %%
def checkIfNecessaryPathsAndFilesExist():
    # if the training directory does not exist, show and error message and bail
    if not os.path.exists(TRAINING_IMAGES_DIR):
        print('')
        print('ERROR: TRAINING_IMAGES_DIR "' + TRAINING_IMAGES_DIR + '" does not seem to exist')
        print('Did you set up the training images?')
        print('')
        return False
    # end if

    # nested class
    class TrainingSubDir:
        # constructor
        def __init__(self):
            self.loc = ""
            self.numImages = 0
        # end constructor
    # end class

    # declare a list of training sub-directories
    trainingSubDirs = []

    # populate the training sub-directories
    for dirName in os.listdir(TRAINING_IMAGES_DIR):
        currentTrainingImagesSubDir = os.path.join(TRAINING_IMAGES_DIR, dirName)
        if os.path.isdir(currentTrainingImagesSubDir):
            trainingSubDir = TrainingSubDir()
            trainingSubDir.loc = currentTrainingImagesSubDir
            trainingSubDirs.append(trainingSubDir)
        # end if
    # end for

    # if no training sub-directories were found, show an error message and return false
    if len(trainingSubDirs) == 0:
        print("ERROR: there don't seem to be any training image sub-directories in " + TRAINING_IMAGES_DIR)
        print("Did you make a separare image sub-directory for each classification type?")
        return False
    # end if

    # populate the number of training images in each training sub-directory
    for trainingSubDir in trainingSubDirs:
        # count how many images are in the current training sub-directory
        for fileName in os.listdir(trainingSubDir.loc):
            if fileName.endswith(".jpg"):
                trainingSubDir.numImages += 1
            # end if
        # end if
    # end for

    # if any training sub-directory has less than the min required number of training images, show an error message and return false
    for trainingSubDir in trainingSubDirs:
        if trainingSubDir.numImages < MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING:
            print("ERROR: there are less than the required " + str(MIN_NUM_IMAGES_REQUIRED_FOR_TRAINING) + " images in " + trainingSubDir.loc)
            print("Did you populate each training sub-directory with images?")
            return False
        # end if
    # end for

    # if any training sub-directory has less than the recommended number of training images, show a warning (but don't return false)
    for trainingSubDir in trainingSubDirs:
        if trainingSubDir.numImages < MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING:
            print("WARNING: there are less than the suggested " + str(MIN_NUM_IMAGES_SUGGESTED_FOR_TRAINING) + " images in " + trainingSubDir.loc)
            print("More images should be added to this directory for acceptable training results")
            # note we do not return false here b/c this is a warning, not an error
        # end if
    # end for

    # if the test images directory does not exist, show and error message and bail
    if not os.path.exists(TEST_IMAGES_DIR):
        print('')
        print('ERROR: TEST_IMAGES_DIR "' + TEST_IMAGES_DIR + '" does not seem to exist')
        print('Did you break out some test images?')
        print('')
        return False
    # end if

    # count how many images are in the test images directory
    numImagesInTestDir = 0
    for fileName in os.listdir(TEST_IMAGES_DIR):
        if fileName.endswith(".jpg"):
            numImagesInTestDir += 1
        # end if
    # end for

    # if there are not enough images in the test images directory, show an error and return false
    if numImagesInTestDir < MIN_NUM_IMAGES_REQUIRED_FOR_TESTING:
        print("ERROR: there are not at least " + str(MIN_NUM_IMAGES_REQUIRED_FOR_TESTING) + " images in " + TEST_IMAGES_DIR)
        print("Did you break out some test images?")
        return False
    # end if

    return True
# end function

# %%
def prepare_file_system():
    # Setup the directory we'll write summaries to for TensorBoard
    if tf.gfile.Exists(TENSORBOARD_DIR):
        tf.gfile.DeleteRecursively(TENSORBOARD_DIR)
    # end if
    tf.gfile.MakeDirs(TENSORBOARD_DIR)
    if INTERMEDIATE_STORE_FREQUENCY > 0:
        makeDirIfDoesNotExist(INTERMEDIATE_OUTPUT_GRAPHS_DIR)
    # end if
    return
# end function

# %%
def makeDirIfDoesNotExist(dir_name):
    """
    Makes sure the folder exists on disk.
    Args:
        dir_name: Path string to the folder we want to create.
    """
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    # end if
# end function

# %%
def create_model_info(architecture):
    """
    Given the name of a model architecture, returns information about it.

    There are different base image recognition pretrained models that can be
    retrained using transfer learning, and this function translates from the name
    of a model to the attributes that are needed to download and train with it.

    Args:
        architecture: Name of a model architecture.

    Returns:
        Dictionary of information about the model, or None if the name isn't recognized

    Raises:
        ValueError: If architecture name is unknown.
    """
    architecture = architecture.lower()
    is_quantized = False
    if architecture == 'inception_v3':
        # pylint: disable=line-too-long
        data_url = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
        # pylint: enable=line-too-long
        bottleneck_tensor_name = 'pool_3/_reshape:0'
        bottleneck_tensor_size = 2048
        input_width = 299
        input_height = 299
        input_depth = 3
        resized_input_tensor_name = 'Mul:0'
        model_file_name = 'classify_image_graph_def.pb'
        input_mean = 128
        input_std = 128
    elif architecture.startswith('mobilenet_'):
        parts = architecture.split('_')
        if len(parts) != 3 and len(parts) != 4:
            tf.logging.error("Couldn't understand architecture name '%s'", architecture)
            return None
        # end if
        version_string = parts[1]
        if (version_string != '1.0' and version_string != '0.75' and version_string != '0.50' and version_string != '0.25'):
            tf.logging.error(""""The Mobilenet version should be '1.0', '0.75', '0.50', or '0.25', but found '%s' for architecture '%s'""", version_string, architecture)
            return None
        # end if
        size_string = parts[2]
        if (size_string != '224' and size_string != '192' and size_string != '160' and size_string != '128'):
            tf.logging.error("""The Mobilenet input size should be '224', '192', '160', or '128', but found '%s' for architecture '%s'""", size_string, architecture)
            return None
        # end if
        if len(parts) == 3:
            is_quantized = False
        else:
            if parts[3] != 'quantized':
                tf.logging.error(
                    "Couldn't understand architecture suffix '%s' for '%s'", parts[3], architecture)
                return None
            is_quantized = True
        # end if

        if is_quantized:
            data_url = 'http://download.tensorflow.org/models/mobilenet_v1_'
            data_url += version_string + '_' + size_string + '_quantized_frozen.tgz'
            bottleneck_tensor_name = 'MobilenetV1/Predictions/Reshape:0'
            resized_input_tensor_name = 'Placeholder:0'
            model_dir_name = ('mobilenet_v1_' + version_string + '_' + size_string + '_quantized_frozen')
            model_base_name = 'quantized_frozen_graph.pb'
        else:
            data_url = 'http://download.tensorflow.org/models/mobilenet_v1_'
            data_url += version_string + '_' + size_string + '_frozen.tgz'
            bottleneck_tensor_name = 'MobilenetV1/Predictions/Reshape:0'
            resized_input_tensor_name = 'input:0'
            model_dir_name = 'mobilenet_v1_' + version_string + '_' + size_string
            model_base_name = 'frozen_graph.pb'
        # end if

        bottleneck_tensor_size = 1001
        input_width = int(size_string)
        input_height = int(size_string)
        input_depth = 3
        model_file_name = os.path.join(model_dir_name, model_base_name)
        input_mean = 127.5
        input_std = 127.5
    else:
        tf.logging.error("Couldn't understand architecture name '%s'", architecture)
        raise ValueError('Unknown architecture', architecture)
    # end if

    return {'data_url': data_url, 'bottleneck_tensor_name': bottleneck_tensor_name, 'bottleneck_tensor_size': bottleneck_tensor_size,
            'input_width': input_width, 'input_height': input_height, 'input_depth': input_depth, 'resized_input_tensor_name': resized_input_tensor_name,
            'model_file_name': model_file_name, 'input_mean': input_mean, 'input_std': input_std, 'quantize_layer': is_quantized, }
# end function

# %%
def downloadModelIfNotAlreadyPresent(data_url):
    """
    Download and extract model tar file.

    If the pretrained model we're using doesn't already exist, this function downloads it from the TensorFlow.org website and unpacks it into a directory.

    Args:
        data_url: Web location of the tar file containing the pretrained model.
    """
    dest_directory = MODEL_DIR
    if not os.path.exists(dest_directory):
        os.makedirs(dest_directory)
    # end if
    filename = data_url.split('/')[-1]
    filepath = os.path.join(dest_directory, filename)
    if not os.path.exists(filepath):
        # nested function
        def _progress(count, block_size, total_size):
            sys.stdout.write('\r>> Downloading %s %.1f%%' % (filename, float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
        # end def

        filepath, _ = urllib.request.urlretrieve(data_url, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        tf.logging.info('Successfully downloaded ' + str(filename) + ', statinfo.st_size = ' + str(statinfo.st_size) + ' bytes')
        print('Extracting file from ', filepath)
        tarfile.open(filepath, 'r:gz').extractall(dest_directory)
    else:
        print('Not extracting or downloading files, model already present in disk')
    # end if
# end function

# %%
def create_model_graph(model_info):
    """"
    Creates a graph from saved GraphDef file and returns a Graph object.

    Args:
        model_info: Dictionary containing information about the model architecture.

    Returns:
        Graph holding the trained Inception network, and various tensors we'll be manipulating.
    """
    with tf.Graph().as_default() as graph:
        model_path = os.path.join(MODEL_DIR, model_info['model_file_name'])
        print('Model path: ', model_path)
        with gfile.FastGFile(model_path, 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            bottleneck_tensor, resized_input_tensor = (tf.import_graph_def(graph_def, name='', return_elements=[model_info['bottleneck_tensor_name'], model_info['resized_input_tensor_name'],]))
        # end with
    # end with
    return graph, bottleneck_tensor, resized_input_tensor
# end function

# %%
def create_image_lists(image_dir, testing_percentage, validation_percentage):
    """
    Builds a list of training images from the file system.

    Analyzes the sub folders in the image directory, splits them into stable
    training, testing, and validation sets, and returns a data structure
    describing the lists of images for each label and their paths.

    Args:
        image_dir: String path to a folder containing subfolders of images.
        testing_percentage: Integer percentage of the images to reserve for tests.
        validation_percentage: Integer percentage of images reserved for validation.

    Returns:
        A dictionary containing an entry for each label subfolder, with images split
        into training, testing, and validation sets within each label.
    """

    # if the image directory does not exist, log an error and bail
    if not gfile.Exists(image_dir):
        tf.logging.error("Image directory '" + image_dir + "' not found.")
        return None
    # end if

    # create an empty dictionary to store the results
    result = {}

    # get a list of the sub-directories of the image directory
    sub_dirs = [x[0] for x in gfile.Walk(image_dir)]

    # for each directory in the sub-directories list . . .
    is_root_dir = True
    for sub_dir in sub_dirs:
        # if we're on the 1st (root) directory, mark our boolean for that as false for the next time around and go back to the top of the for loop
        if is_root_dir:
            is_root_dir = False
            continue
        # end if

        dir_name = os.path.basename(sub_dir)
        if dir_name == image_dir:
            continue
        # end if

        # ToDo: This section should be refactored.  The right way to do this would be to get a list of the files that are
        # ToDo: there then append (extend) those, not to get the name except the extension, then append an extension,
        # ToDo: this (current) way is error prone of the original file has an upper case or mixed case extension

        extensions = ['jpg', 'jpeg']
        file_list = []
        tf.logging.info("Looking for images in '" + dir_name + "'")
        for extension in extensions:
            file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
            file_list.extend(gfile.Glob(file_glob))
        # end for

        # if the file list is empty at this point, log a warning and bail
        if not file_list:
            tf.logging.warning('No files found')
            continue
        # end if

        # if the length of the file list is less than 20 or more than the max number, log an applicable warning (do not return, however)
        if len(file_list) < 20:
            tf.logging.warning('WARNING: Folder has less than 20 images, which may cause issues.')
        elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
            tf.logging.warning('WARNING: Folder {} has more than {} images. Some images will never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
        # end if

        label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
        training_images = []
        testing_images = []
        validation_images = []
        for file_name in file_list:
            base_name = os.path.basename(file_name)
            # We want to ignore anything after '_nohash_' in the file name when deciding which set to put an image in, the data set creator
            # has a way of grouping photos that are close variations of each other. For example this is used in the plant disease data set
            # to group multiple pictures of the same leaf.
            hash_name = re.sub(r'_nohash_.*$', '', file_name)
            # This looks a bit magical, but we need to decide whether this file should go into the training, testing, or validation sets,
            # and we want to keep existing files in the same set even if more files are subsequently added.  To do that, we need a stable
            # way of deciding based on just the file name itself, so we do a hash of that and then use that to generate a probability value
            # that we use to assign it.
            hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
            percentage_hash = ((int(hash_name_hashed, 16) % (MAX_NUM_IMAGES_PER_CLASS + 1)) * (100.0 / MAX_NUM_IMAGES_PER_CLASS))
            if percentage_hash < validation_percentage:
                validation_images.append(base_name)
            elif percentage_hash < (testing_percentage + validation_percentage):
                testing_images.append(base_name)
            else:
                training_images.append(base_name)
            # end if
        result[label_name] = {'dir': dir_name, 'training': training_images, 'testing': testing_images, 'validation': validation_images,}
    return result
# end function

# %%
def add_jpeg_decoding(input_width, input_height, input_depth, input_mean, input_std):
    """
    Adds operations that perform JPEG decoding and resizing to the graph..
    Args:
        input_width: Desired width of the image fed into the recognizer graph.
        input_height: Desired width of the image fed into the recognizer graph.
        input_depth: Desired channels of the image fed into the recognizer graph.
        input_mean: Pixel value that should be zero in the image for the graph.
        input_std: How much to divide the pixel values by before recognition.

    Returns:
        Tensors for the node to feed JPEG data into, and the output of the preprocessing steps.
    """
    jpeg_data = tf.placeholder(tf.string, name='DecodeJPGInput')
    decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
    decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
    decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
    resize_shape = tf.stack([input_height, input_width])
    resize_shape_as_int = tf.cast(resize_shape, dtype=tf.int32)
    resized_image = tf.image.resize_bilinear(decoded_image_4d, resize_shape_as_int)
    offset_image = tf.subtract(resized_image, input_mean)
    mul_image = tf.multiply(offset_image, 1.0 / input_std)
    return jpeg_data, mul_image
# end function

# %%
def add_input_distortions(flip_left_right, random_crop, random_scale, random_brightness, input_width, input_height,
                          input_depth, input_mean, input_std):
    """
    Creates the operations to apply the specified distortions.

    During training it can help to improve the results if we run the images
    through simple distortions like crops, scales, and flips. These reflect the
    kind of variations we expect in the real world, and so can help train the
    model to cope with natural data more effectively. Here we take the supplied
    parameters and construct a network of operations to apply them to an image.

    Cropping
    ~~~~~~~~

    Cropping is done by placing a bounding box at a random position in the full
    image. The cropping parameter controls the size of that box relative to the
    input image. If it's zero, then the box is the same size as the input and no
    cropping is performed. If the value is 50%, then the crop box will be half the
    width and height of the input. In a diagram it looks like this:

    <       width         >
    +---------------------+
    |                     |
    |   width - crop%     |
    |    <      >         |
    |    +------+         |
    |    |      |         |
    |    |      |         |
    |    |      |         |
    |    +------+         |
    |                     |
    |                     |
    +---------------------+

    Scaling
    ~~~~~~~

    Scaling is a lot like cropping, except that the bounding box is always
    centered and its size varies randomly within the given range. For example if
    the scale percentage is zero, then the bounding box is the same size as the
    input and no scaling is applied. If it's 50%, then the bounding box will be in
    a random range between half the width and height and full size.

    Args:
        flip_left_right: Boolean whether to randomly mirror images horizontally.
        random_crop: Integer percentage setting the total margin used around the
        crop box.
        random_scale: Integer percentage of how much to vary the scale by.
        random_brightness: Integer range to randomly multiply the pixel values by.
        graph.
        input_width: Horizontal size of expected input image to model.
        input_height: Vertical size of expected input image to model.
        input_depth: How many channels the expected input image should have.
        input_mean: Pixel value that should be zero in the image for the graph.
        input_std: How much to divide the pixel values by before recognition.

    Returns:
        The jpeg input layer and the distorted result tensor.
    """

    jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
    decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
    decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
    decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
    margin_scale = 1.0 + (random_crop / 100.0)
    resize_scale = 1.0 + (random_scale / 100.0)
    margin_scale_value = tf.constant(margin_scale)
    resize_scale_value = tf.random_uniform(tensor_shape.scalar(), minval=1.0, maxval=resize_scale)
    scale_value = tf.multiply(margin_scale_value, resize_scale_value)
    precrop_width = tf.multiply(scale_value, input_width)
    precrop_height = tf.multiply(scale_value, input_height)
    precrop_shape = tf.stack([precrop_height, precrop_width])
    precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
    precropped_image = tf.image.resize_bilinear(decoded_image_4d, precrop_shape_as_int)
    precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
    cropped_image = tf.random_crop(precropped_image_3d, [input_height, input_width, input_depth])
    if flip_left_right:
        flipped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        flipped_image = cropped_image
    # end if
    brightness_min = 1.0 - (random_brightness / 100.0)
    brightness_max = 1.0 + (random_brightness / 100.0)
    brightness_value = tf.random_uniform(tensor_shape.scalar(), minval=brightness_min, maxval=brightness_max)
    brightened_image = tf.multiply(flipped_image, brightness_value)
    offset_image = tf.subtract(brightened_image, input_mean)
    mul_image = tf.multiply(offset_image, 1.0 / input_std)
    distort_result = tf.expand_dims(mul_image, 0, name='DistortResult')
    return jpeg_data, distort_result
# end function

# %%
def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir, jpeg_data_tensor, decoded_image_tensor,
                      resized_input_tensor, bottleneck_tensor, architecture):
    """
    Ensures all the training, testing, and validation bottlenecks are cached.

    Because we're likely to read the same image multiple times (if there are no distortions applied during training) it
    can speed things up a lot if we calculate the bottleneck layer values once for each image during preprocessing,
    and then just read those cached values repeatedly during training. Here we go through all the images we've found,
    calculate those values, and save them off.

    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        image_dir: Root folder string of the subfolders containing the training images.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: Input tensor for jpeg data from file.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The penultimate output layer of the graph.
        architecture: The name of the model architecture.

    Returns:
        Nothing.
    """
    how_many_bottlenecks = 0
    makeDirIfDoesNotExist(bottleneck_dir)
    for label_name, label_lists in image_lists.items():
        for category in ['training', 'testing', 'validation']:
            category_list = label_lists[category]
            for index, unused_base_name in enumerate(category_list):
                get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir, category, bottleneck_dir,
                                         jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
            # end for
            how_many_bottlenecks += 1
            if how_many_bottlenecks % 100 == 0:
                tf.logging.info(str(how_many_bottlenecks) + ' bottleneck files created.')
            # end if
# end function

# %%
def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir, category, bottleneck_dir, jpeg_data_tensor,
                             decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture):
    """
    Retrieves or calculates bottleneck values for an image.

    If a cached version of the bottleneck data exists on-disk, return that, otherwise calculate the data and save it to disk for future use.

    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be modulo-ed by the available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string of the subfolders containing the training images.
        category: Name string of which set to pull images from - training, testing, or validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: The tensor to feed loaded jpeg data into.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The output tensor for the bottleneck values.
        architecture: The name of the model architecture.

    Returns:
        Numpy array of values produced by the bottleneck layer for the image.
    """
    label_lists = image_lists[label_name]
    sub_dir = label_lists['dir']
    sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
    makeDirIfDoesNotExist(sub_dir_path)
    bottleneck_path = get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category, architecture)
    if not os.path.exists(bottleneck_path):
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor,
                               decoded_image_tensor, resized_input_tensor, bottleneck_tensor)
    # end if

    # read in the contents of the bottleneck file as one big string
    with open(bottleneck_path, 'r') as bottleneck_file:
        bottleneckBigString = bottleneck_file.read()
    # end with

    bottleneckValues = []
    errorOccurred = False
    try:
        # split the bottleneck file contents read in as one big string into individual float values
        bottleneckValues = [float(individualString) for individualString in bottleneckBigString.split(',')]
    except ValueError:
        tf.logging.warning('Invalid float found, recreating bottleneck')
        errorOccurred = True
    # end try

    if errorOccurred:
        # if an error occurred above, create (or re-create) the bottleneck file
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess,
                               jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor)

        # read in the contents of the newly created bottleneck file
        with open(bottleneck_path, 'r') as bottleneck_file:
            bottleneckBigString = bottleneck_file.read()
        # end with

        # split the bottleneck file contents read in as one big string into individual float values again
        bottleneckValues = [float(individualString) for individualString in bottleneckBigString.split(',')]
    # end if
    return bottleneckValues
# end function

# %%
def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category, architecture):
    """"
    Returns a path to a bottleneck file for a label at the given index.

    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be moduloed by the
        available number of images for the label, so it can be arbitrarily large.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        category: Name string of set to pull images from - training, testing, or
        validation.
        architecture: The name of the model architecture.

    Returns:
        File system path string to an image that meets the requested parameters.
    """
    return get_image_path(image_lists, label_name, index, bottleneck_dir, category) + '_' + architecture + '.txt'
# end function

# %%
def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           decoded_image_tensor, resized_input_tensor,
                           bottleneck_tensor):
    """Create a single bottleneck file."""
    tf.logging.info('Creating bottleneck at ' + bottleneck_path)
    image_path = get_image_path(image_lists, label_name, index, image_dir, category)
    if not gfile.Exists(image_path):
        tf.logging.fatal('File does not exist %s', image_path)
    # end if
    image_data = gfile.FastGFile(image_path, 'rb').read()
    try:
        bottleneck_values = run_bottleneck_on_image(sess, image_data, jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor)
    except Exception as e:
        raise RuntimeError('Error during processing file %s (%s)' % (image_path, str(e)))
    # end try

    bottleneck_string = ','.join(str(x) for x in bottleneck_values)
    with open(bottleneck_path, 'w') as bottleneck_file:
        bottleneck_file.write(bottleneck_string)
    # end with
# end function

# %%
def run_bottleneck_on_image(sess, image_data, image_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor):
    """
    Runs inference on an image to extract the 'bottleneck' summary layer.
    Args:
        sess: Current active TensorFlow Session.
        image_data: String of raw JPEG data.
        image_data_tensor: Input data layer in the graph.
        decoded_image_tensor: Output of initial image resizing and preprocessing.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: Layer before the final softmax.

    Returns:
        Numpy array of bottleneck values.
    """
    # First decode the JPEG image, resize it, and rescale the pixel values.
    resized_input_values = sess.run(decoded_image_tensor, {image_data_tensor: image_data})
    # Then run it through the recognition network.
    bottleneck_values = sess.run(bottleneck_tensor, {resized_input_tensor: resized_input_values})
    bottleneck_values = np.squeeze(bottleneck_values)
    return bottleneck_values
# end function

# %%
def get_image_path(image_lists, label_name, index, image_dir, category):
    """"
    Returns a path to an image for a label at the given index.

    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Int offset of the image we want. This will be moduloed by the available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string of the subfolders containing the training images.
        category: Name string of set to pull images from - training, testing, or validation.

    Returns:
        File system path string to an image that meets the requested parameters.
    """
    if label_name not in image_lists:
        tf.logging.fatal('Label does not exist %s.', label_name)
    # end if
    label_lists = image_lists[label_name]
    if category not in label_lists:
        tf.logging.fatal('Category does not exist %s.', category)
    # end if
    category_list = label_lists[category]
    if not category_list:
        tf.logging.fatal('Label %s has no images in the category %s.', label_name, category)
    # end if
    mod_index = index % len(category_list)
    base_name = category_list[mod_index]
    sub_dir = label_lists['dir']
    full_path = os.path.join(image_dir, sub_dir, base_name)
    return full_path
# end function

# %%
def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor, bottleneck_tensor_size, quantize_layer):
    """
    Adds a new softmax and fully-connected layer for training.

    We need to retrain the top layer to identify our new classes, so this function
    adds the right operations to the graph, along with some variables to hold the
    weights, and then sets up all the gradients for the backward pass.

    The set up for the softmax and fully-connected layers is based on:
    https://www.tensorflow.org/versions/master/tutorials/mnist/beginners/index.html

    Args:
        class_count: Integer of how many categories of things we're trying to recognize.
        final_tensor_name: Name string for the new final node that produces results.
        bottleneck_tensor: The output of the main CNN graph.
        bottleneck_tensor_size: How many entries in the bottleneck vector.
        quantize_layer: Boolean, specifying whether the newly added layer should be quantized.

    Returns:
        The tensors for the training and cross entropy results, and tensors for the bottleneck input and ground truth input.
    """
    with tf.name_scope('input'):
        bottleneck_input = tf.placeholder_with_default(bottleneck_tensor, shape=[None, bottleneck_tensor_size], name='BottleneckInputPlaceholder')
        ground_truth_input = tf.placeholder(tf.int64, [None], name='GroundTruthInput')
    # end with

    # Organizing the following ops as `final_training_ops` so they're easier to see in TensorBoard
    layer_name = 'final_training_ops'
    with tf.name_scope(layer_name):
        quantized_layer_weights = None
        quantized_layer_biases = None
        with tf.name_scope('weights'):
            initial_value = tf.truncated_normal([bottleneck_tensor_size, class_count], stddev=0.001)
            layer_weights = tf.Variable(initial_value, name='final_weights')
            if quantize_layer:
                quantized_layer_weights = quant_ops.MovingAvgQuantize(layer_weights, is_training=True)
                attachTensorBoardSummaries(quantized_layer_weights)
            # end if

            # this comment is necessary to suppress an unnecessary PyCharm warning
            # noinspection PyTypeChecker
            attachTensorBoardSummaries(layer_weights)
        # end with
        with tf.name_scope('biases'):
            layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
            if quantize_layer:
                quantized_layer_biases = quant_ops.MovingAvgQuantize(layer_biases, is_training=True)
                attachTensorBoardSummaries(quantized_layer_biases)
            # end if

            # this comment is necessary to suppress an unnecessary PyCharm warning
            # noinspection PyTypeChecker
            attachTensorBoardSummaries(layer_biases)
        # end with
        with tf.name_scope('Wx_plus_b'):
            if quantize_layer:
                logits = tf.matmul(bottleneck_input, quantized_layer_weights) + quantized_layer_biases
                logits = quant_ops.MovingAvgQuantize(logits, init_min=-32.0, init_max=32.0, is_training=True, num_bits=8,
                                                     narrow_range=False, ema_decay=0.5)
                tf.summary.histogram('pre_activations', logits)
            else:
                logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
                tf.summary.histogram('pre_activations', logits)
            # end if
        # end with
    # end with
    final_tensor = tf.nn.softmax(logits, name=final_tensor_name)

    tf.summary.histogram('activations', final_tensor)

    with tf.name_scope('cross_entropy'):
        cross_entropy_mean = tf.losses.sparse_softmax_cross_entropy(labels=ground_truth_input, logits=logits)
    # end with

    tf.summary.scalar('cross_entropy', cross_entropy_mean)

    with tf.name_scope('train'):
        optimizer = tf.train.GradientDescentOptimizer(LEARNING_RATE)
        train_step = optimizer.minimize(cross_entropy_mean)
    # end with

    return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input, final_tensor)
# end function

# %%
def attachTensorBoardSummaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        # end with
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)
    # end with
# end function

# %%
def add_evaluation_step(result_tensor, ground_truth_tensor):
    """
    Inserts the operations we need to evaluate the accuracy of our results.
    Args:
        result_tensor: The new final node that produces results.
        ground_truth_tensor: The node we feed ground truth data into.
    Returns:
        Tuple of (evaluation step, prediction).
    """

    with tf.name_scope('accuracy'):
        with tf.name_scope('correct_prediction'):
            prediction = tf.argmax(result_tensor, 1)
            correct_prediction = tf.equal(prediction, ground_truth_tensor)
        # end with
        with tf.name_scope('accuracy'):
            evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        # end with
    tf.summary.scalar('accuracy', evaluation_step)
    return evaluation_step, prediction
# end function

# %%
def get_random_distorted_bottlenecks(sess, image_lists, how_many, category, image_dir, input_jpeg_tensor, distorted_image,
                                     resized_input_tensor, bottleneck_tensor):
    """
    Retrieves bottleneck values for training images, after distortions.

    If we're training with distortions like crops, scales, or flips, we have to recalculate the full model for every image,
    and so we can't use cached bottleneck values. Instead we find random images for the requested category, run them through
    the distortion graph, and then the full graph to get the bottleneck results for each.

    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: The integer number of bottleneck values to return.
        category: Name string of which set of images to fetch - training, testing, or validation.
        image_dir: Root folder string of the subfolders containing the training images.
        input_jpeg_tensor: The input layer we feed the image data to.
        distorted_image: The output node of the distortion graph.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.

    Returns:
        List of bottleneck arrays and their corresponding ground truths.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    for unused_i in range(how_many):
        label_index = random.randrange(class_count)
        label_name = list(image_lists.keys())[label_index]
        image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
        image_path = get_image_path(image_lists, label_name, image_index, image_dir, category)
        if not gfile.Exists(image_path):
            tf.logging.fatal('File does not exist %s', image_path)
        # end if
        jpeg_data = gfile.FastGFile(image_path, 'rb').read()
        # Note that we materialize the distorted_image_data as a numpy array before
        # sending running inference on the image. This involves 2 memory copies and
        # might be optimized in other implementations.
        distorted_image_data = sess.run(distorted_image, {input_jpeg_tensor: jpeg_data})
        bottleneck_values = sess.run(bottleneck_tensor, {resized_input_tensor: distorted_image_data})
        bottleneck_values = np.squeeze(bottleneck_values)
        bottlenecks.append(bottleneck_values)
        ground_truths.append(label_index)
    # end for
    return bottlenecks, ground_truths
# end function

# %%
def get_random_cached_bottlenecks(sess, image_lists, how_many, category, bottleneck_dir, image_dir, jpeg_data_tensor,
                                  decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture):
    """
    Retrieves bottleneck values for cached images.

    If no distortions are being applied, this function can retrieve the cached bottleneck values directly from disk for
    images. It picks a random set of images from the specified category.

    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: If positive, a random sample of this size will be chosen.  If negative, all bottlenecks will be retrieved.
        category: Name string of which set to pull from - training, testing, or validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        image_dir: Root folder string of the subfolders containing the training images.
        jpeg_data_tensor: The layer to feed jpeg image data into.
        decoded_image_tensor: The output of decoding and resizing the image.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.
        architecture: The name of the model architecture.

    Returns:
        List of bottleneck arrays, their corresponding ground truths, and the relevant filenames.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    filenames = []
    if how_many >= 0:
        # Retrieve a random sample of bottlenecks.
        for unused_i in range(how_many):
            label_index = random.randrange(class_count)
            label_name = list(image_lists.keys())[label_index]
            image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
            image_name = get_image_path(image_lists, label_name, image_index, image_dir, category)
            bottleneck = get_or_create_bottleneck(sess, image_lists, label_name, image_index, image_dir, category, bottleneck_dir,
                                                  jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
            bottlenecks.append(bottleneck)
            ground_truths.append(label_index)
            filenames.append(image_name)
        # end for
    else:
        # Retrieve all bottlenecks.
        for label_index, label_name in enumerate(image_lists.keys()):
            for image_index, image_name in enumerate(image_lists[label_name][category]):
                image_name = get_image_path(image_lists, label_name, image_index, image_dir, category)
                bottleneck = get_or_create_bottleneck(sess, image_lists, label_name, image_index, image_dir, category, bottleneck_dir,
                                                      jpeg_data_tensor, decoded_image_tensor, resized_input_tensor, bottleneck_tensor, architecture)
                bottlenecks.append(bottleneck)
                ground_truths.append(label_index)
                filenames.append(image_name)
    return bottlenecks, ground_truths, filenames
# end function

# %%
def save_graph_to_file(sess, graph, graph_file_name):
    output_graph_def = graph_util.convert_variables_to_constants(sess, graph.as_graph_def(), [FINAL_TENSOR_NAME])
    with gfile.FastGFile(graph_file_name, 'wb') as f:
        f.write(output_graph_def.SerializeToString())
    # end with
    return
# end function

# %%
if __name__ == '__main__':
    main()
# Out:
# starting program . . .
# downloading model (if necessary) . . .
# >> Downloading inception-2015-12-05.tgz 100.0%
# INFO:tensorflow:Successfully downloaded inception-2015-12-05.tgz, statinfo.st_size = 88931400 bytes
# Extracting file from  C:\Users\Michael\NW University/model\inception-2015-12-05.tgz
# creating model graph . . .
# Model path:  C:\Users\Michael\NW University/model\classify_image_graph_def.pb
# WARNING:tensorflow:From <ipython-input-9-7c4c0442c084>:14: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# creating image lists . . .
# INFO:tensorflow:Looking for images in 'daisy'
# INFO:tensorflow:Looking for images in 'dandelion'
# INFO:tensorflow:Looking for images in 'roses'
# INFO:tensorflow:Looking for images in 'sunflowers'
# INFO:tensorflow:Looking for images in 'tulips'
# starting session . . .
# performing jpeg decoding . . .
# caching bottlenecks . . .
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10140303196_b88d3d6cec.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10172379554_b296050f82_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10172567486_2748826a8b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10172636503_21bededa75_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1031799732_e7f4008c03.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10391248763_1d16681106_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10437754174_22ec990b77_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10437929963_bc13eebe0c.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10466290366_cc72e33532.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10466558316_a7198b87e2.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10555749515_13a12a026e.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10555815624_dc211569b0.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10559679065_50d2b16f6d.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10712722853_5632165b04.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10993818044_4c19b86c82.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\10994032453_ac7f8d9e2e.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\11023214096_b5b39fab08.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\11124324295_503f3a0804.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1150395827_6f94a5c6e4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\11834945233_a53b7a92ac_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\11870378973_2ec1919f12.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\11891885265_ccefec7284_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\12348343085_d4c396e5b5_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\12585131704_0f64b17059_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\12601254324_3cb62c254a_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1265350143_6e2b276ec9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1286274236_1d7ac84efb_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\12891819633_e4c82b51e8.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1299501272_59d9da5510_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1306119996_ab8ae14d72_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1314069875_da8dc023c6_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\134409839_71069a95d1_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1344985627_c3115e2d71_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\13491959645_2cd9df44d6_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1355787476_32e9f2a30b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\13583238844_573df2de8e_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1374193928_a52320eafa.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1392946544_115acbb2d9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\13953307149_f8de6a768c_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1396526833_fb867165be_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\13977181862_f8237b6b52.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14021430525_e06baf93a9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14073784469_ffb12f3387_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14087947408_9779257411_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14088053307_1a13a0bf91_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14163875973_467224aaf5_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14167534527_781ceb1b7a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14167543177_cd36b54ac6_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14219214466_3ca6104eae_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14221848160_7f0a37c395.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14245834619_153624f836.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14264136211_9531fbc144.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14272874304_47c0a46f5a.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14330343061_99478302d4_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14332947164_9b13513c71_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14333681205_a07c9f1752_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14372713423_61e2daae88.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14399435971_ea5868c792.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\144099102_bf63a41e4f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1441939151_b271408c8d_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14421389519_d5fd353eb4.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\144603918_b9de002f60_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14471433500_cdaa22e3ea_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14485782498_fb342ec301.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14523675369_97c31d0b5b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14554906452_35f066ffe9_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14564545365_1f1d267bf1_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14569895116_32f0dcb0f9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14591326135_930703dbed_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14613443462_d4ed356201.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14674743211_f68b13f6d9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14698531521_0c2f0c6539.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14707111433_cce08ee007.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14716799982_ed6d626a66.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14816364517_2423021484_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14866200659_6462c723cb_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\14907815010_bff495449f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15029936576_8d6f96c72c_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15306268004_4680ba95e1.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15327813273_06cdf42210.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15760153042_a2a90e9da5_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15760811380_4d686c892b_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15784493690_b1858cdb2b_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15813862117_dedcd1c56f_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\15853110333_229c439e7f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16025261368_911703a536_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16121105382_b96251e506_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16161045294_70c76ce846_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16291797949_a1b1b7c2bd_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16360180712_b72695928c_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16401288243_36112bd52f_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16482676953_5296227d40_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16527403771_2391f137c4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1656856503_447e5b0f03.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16819071290_471d99e166_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\16833748795_b681b2839f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\17027891179_3edc08f4f6.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\171972704_389cf7a953.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\172882635_4cc7b86731_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\172967318_c596d082cc.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\173350276_02817aa8d5.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\17357636476_1953c07aa4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\174131220_c853df1287.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\181007802_7cab5ee78e_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18195689904_46619b7e16_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18203367608_07a04e98a4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18354545086_693ea7bc2a.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18400014056_2e4c601ed5.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18622672908_eab6dc9140_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18635898912_eb8e058ef0.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18679421522_3be9879e32.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18684594849_7dd3634f5e_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18711159980_11d3bd5042.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1879567877_8ed2a5faa7_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\18901817451_43e2b45f6c.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19019544592_b64469bf84_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19178753159_a471bf4b6b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19280272025_57de24e940_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19544831049_0d738d4872_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\1955336401_fbb206d6ef_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19653086178_28156b7ce4_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19813618946_93818db7aa_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19834392829_7d697871f6.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\19975899671_ebc42b7865_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2001380507_19488ff96a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2019064575_7656b9340f_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20289938802_e16fa9f23d.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20329326505_a777c71cc2.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2045022175_ad087f5f60_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20619292635_9857a12d54.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20703737132_179560d0fb.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20773528301_008fcbc5a1_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2077865117_9ed85191ae_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2087343668_ef4fb95787_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\20948886919_cac7844f34_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\21652746_cc379e0eea_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\21805938544_bf6bb0e4bc.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\22244161124_53e457bb66_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\22873310415_3a5674ec10_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\23095658544_7226386954_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2331133004_582772d58f_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2346726545_2ebce2b2a6.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2351206867_084e57bd97.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2365428551_39f83f10bf_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2408024540_37f0be7cc0_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2454280135_ac3aa75cdc_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2454280137_e1637536ae_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2473825306_62fd5f8785_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2476937534_21b285aa46_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2479956481_8d1a9699be_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2481823240_eab0d86921.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2488902131_3417698611_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2498632196_e47a472d5a.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2509545845_99e79cb8a2_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2513618768_ff7c004796_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2514748602_343d4727c0_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2520369272_1dcdb5a892_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2521408074_e6f86daf21_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\253426762_9793d43fcd.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\25360380_1a881a5648.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2538504987_fe524b92a8_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2539552964_921cf645ba_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2551708158_1f10e81e11.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2556503265_63ae6b9e0e_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2573240560_ff7ffdd449.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2578695910_5ab8ee17c1_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2579018590_74359dcf1a_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2581171297_b0a249b92b_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2590291468_2635d3e4e0_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2599662355_7782218c83.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2607132536_d95198e619_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2617111535_54c2ac8462.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2619413565_61a6cd3ac9_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2621723097_736febb4a4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2627815904_919373e7f5.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2632216904_274aa17433.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2635314490_e12d3b0f36_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2641151167_3bf1349606_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2641979584_2b21c3fe29_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2646438199_b309cffd65_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2649404904_b7a91991bb_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2666572212_2caca8de9f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\267148092_4bb874af58.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2812442552_3eed5fb9f2_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2828733818_1c1ed0089d_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\286875003_f7c0e1882d.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2877860110_a842f8b14a_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2889325612_f2fc403ff0_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\2901376034_cdb4bac26b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\294451721_5106537b34.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\299129811_d6ebda9970.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\301964511_fab84ea1c1.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3025866885_22fb0b61c6_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\302782756_d35cb3e468.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\305160642_53cde0f44f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3080880039_4f1bd592e5_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3084924076_4d5c5711af_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3117644024_1cbb59a509_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3285641623_da0e47f49a.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3326037909_b5ae370722_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3336704121_cfeb67a7d7.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3337536080_1db19964fe.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3337643329_accc9b5426.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3356112863_75da8bca2c_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3379332157_04724f6480.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3386988684_bc5a66005e.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3415180846_d7b5cced14_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3440366251_5b9bdf27c9_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3445110406_0c1616d2e3_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3456403987_5bd5fa6ece_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3463313493_9497aa47e5_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3468498624_d082f99e98.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3474942718_c418dae6f1.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3475870145_685a19116d.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3483303007_42e3f90da7.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3491933306_43cfe2cfbe.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3494265422_9dba8f2191_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3504430338_77d6a7fab4_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3533954656_79156c8473.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3546455114_cd2dea5e02.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3552074420_2a0a7166db_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3598615130_578ed30e5f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3611577717_f3a7a8c416_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3625257860_33efeef614_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3628485766_4ff937954a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3633489595_a037a9b7a4_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3637428148_a1dcccafa9_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3639009391_0f910681b7.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3640845041_80a92c4205_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3661613900_b15ca1d35d_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\367020749_3c9a652d75.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3695826945_9f374e8a00_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3699235066_fc09a02dfe_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3703643767_dee82cdef9_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3704305945_a80e60e2f6_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3704306975_75b74497d8.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3706420943_66f3214862_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3711723108_65247a3170.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3711892138_b8c953fdc1_z.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3713290261_8a66de23ab.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3717746329_53f515c6a6_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3720632920_93cf1cc7f3_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3750250718_eb61146c5f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3758221664_b19116d61f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3773181799_5def396456.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3780380240_ef9ec1b737_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3848258315_ed2fde4fb4.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\391364010_4b0942d400_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3939135368_0af5c4982a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3957488431_52a447c0e8_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3962240986_0661edc43a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3963330924_6c6a3fa7be_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3975010332_3209f9f447_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\3999978867_c67c79597f_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4065883015_4bb6010cb7_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4117918318_3c8935289b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4131565290_0585c4dd5a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4141147800_813f660b47.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4144275653_7c02d47d9b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\422094774_28acc69a8b_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4222584034_8964cbd3de.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4229503616_9b8a42123c_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4258408909_b7cc92741c_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4268817944_cdbdb226ae.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4276898893_609d11db8b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4278442064_a5a598524b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4281102584_c548a69b81_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4286053334_a75541f20b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4301689054_20519e5b68.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\433037739_6a030e5912.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4333085242_bbeb3e2841_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\433837534_1dbf798b73.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\43474673_7bb4465a86.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\437859108_173fb33c98.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4407065098_ef25f1ccac_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4413849849_b8d2f3bcf1_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4432271543_01c56ca3a9.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4434592930_6610d51fca_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4440480869_632ce6aff3_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\446484749_4044affcaf_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4482623536_b9fb5ae41f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4496202781_1d8e776ff5_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4511693548_20f9bd2b9c_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\452854574_59492f119a_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4534460263_8e9611db3c_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4538877108_3c793f7987_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4540555191_3254dc4608_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4544110929_a7de65d65f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4561871220_47f420ca59_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4563059851_45a9d21a75.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4565255237_9ba29c4d4e_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4581199679_867652c3f1_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4598422221_b37313a3e3_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\459931395_24bf6531fe_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4613992315_143ccc2a10_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4646886118_b5c5ceaf6d_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4657354814_f368762c53_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4666648087_b10f376f19.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4668543441_79040ca329_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4669117051_ce61e91b76.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4694730335_2553e77aa5_z.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4694734757_5c563d38dd_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4697206799_19dd2a3193_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4724713781_d169f98a35.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4727955343_0bb23ac4ae.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4746633946_23933c0810.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4753134939_8e87649db6.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4757448834_a29a9538c9_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\476856232_7c35952f40_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\483886997_27ee798327.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4858518329_7563eb0baa_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4861391074_c3e122dab0_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\488202750_c420cbce61.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4890424315_6a59696357_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4897587985_f9293ea1ed.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\4923279674_e7f8e70794_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5014137563_d03eb0ed75_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5054771689_00dd40b971_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\506018088_4f7a15a7c5_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\506348009_9ecff8b6ef.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\506493250_e9ca42fe3d.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5087720485_c0914fb623.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\510844526_858b8fe4db.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5109508979_68e3530791_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5110107234_12ddc0206b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5110109540_beed4ed162_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5110110938_9da91455c4_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\512177035_70afc925c8.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5133243796_44de429de5_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5135131051_102d4878ca_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\515112668_a49c69455a.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\517054467_d82d323c33_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\519880292_7a3a6c6b69.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\520752848_4b87fb91a4.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\521762040_f26f2e08dd.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\525271784_013ddccd1b_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\525780443_bba812c26a_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\530738000_4df7e4786b.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\534547364_3f6b7279d2_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5434742166_35773eba57_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5434901893_4550be3f84_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5434914569_e9b982fde0_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5435513198_90ce39f1aa_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\daisy\5435521200_92029bbe2b_n.jpg_inception_v3.txt
# ...
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\7481217920_6f65766a1c_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\779359602_30abcbf5bb_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8554190977_37ac747799_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8555123165_2fe57eff4f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8572847041_d0cc07861f_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8687675254_c93f50d8b0_m.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8712267391_c756f18ee7_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8713392604_90631fb809_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8713397694_bcbcbba2c2_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8713398906_28e59a225a_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8762189906_8223cef62f.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\8817622133_a42bb90e38_n.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\9019694597_2d3bbedb17.jpg_inception_v3.txt
# INFO:tensorflow:Creating bottleneck at C:\Users\Michael\NW University/bottleneck_data\tulips\9444202147_405290415b_n.jpg_inception_v3.txt
# adding final training layer . . .
# WARNING:tensorflow:From C:\Users\Michael\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Michael\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# adding eval ops for final training layer . . .
# writing TensorBoard info . . .
# performing training . . .
# INFO:tensorflow:2019-08-26 08:24:13.307076: Step 0: Train accuracy = 47.0%
# INFO:tensorflow:2019-08-26 08:24:13.308079: Step 0: Cross entropy = 1.530119
# INFO:tensorflow:2019-08-26 08:24:16.680042: Step 0: Validation accuracy = 38.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:18.297660: Step 10: Train accuracy = 77.0%
# INFO:tensorflow:2019-08-26 08:24:18.298165: Step 10: Cross entropy = 1.137114
# INFO:tensorflow:2019-08-26 08:24:18.454363: Step 10: Validation accuracy = 67.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:19.936057: Step 20: Train accuracy = 81.0%
# INFO:tensorflow:2019-08-26 08:24:19.936558: Step 20: Cross entropy = 0.937565
# INFO:tensorflow:2019-08-26 08:24:20.093741: Step 20: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:21.570087: Step 30: Train accuracy = 76.0%
# INFO:tensorflow:2019-08-26 08:24:21.571588: Step 30: Cross entropy = 0.840285
# INFO:tensorflow:2019-08-26 08:24:21.723189: Step 30: Validation accuracy = 76.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:23.224761: Step 40: Train accuracy = 81.0%
# INFO:tensorflow:2019-08-26 08:24:23.226262: Step 40: Cross entropy = 0.799797
# INFO:tensorflow:2019-08-26 08:24:23.376972: Step 40: Validation accuracy = 78.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:25.015138: Step 50: Train accuracy = 85.0%
# INFO:tensorflow:2019-08-26 08:24:25.017139: Step 50: Cross entropy = 0.689156
# INFO:tensorflow:2019-08-26 08:24:25.199357: Step 50: Validation accuracy = 80.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:26.682101: Step 60: Train accuracy = 84.0%
# INFO:tensorflow:2019-08-26 08:24:26.683101: Step 60: Cross entropy = 0.682479
# INFO:tensorflow:2019-08-26 08:24:26.837769: Step 60: Validation accuracy = 86.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:28.316619: Step 70: Train accuracy = 84.0%
# INFO:tensorflow:2019-08-26 08:24:28.317620: Step 70: Cross entropy = 0.693298
# INFO:tensorflow:2019-08-26 08:24:28.491836: Step 70: Validation accuracy = 83.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:29.965445: Step 80: Train accuracy = 80.0%
# INFO:tensorflow:2019-08-26 08:24:29.966946: Step 80: Cross entropy = 0.659634
# INFO:tensorflow:2019-08-26 08:24:30.127134: Step 80: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:31.603241: Step 90: Train accuracy = 86.0%
# INFO:tensorflow:2019-08-26 08:24:31.604242: Step 90: Cross entropy = 0.529942
# INFO:tensorflow:2019-08-26 08:24:31.757866: Step 90: Validation accuracy = 83.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:33.239713: Step 100: Train accuracy = 82.0%
# INFO:tensorflow:2019-08-26 08:24:33.240717: Step 100: Cross entropy = 0.593519
# INFO:tensorflow:2019-08-26 08:24:33.400644: Step 100: Validation accuracy = 77.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:34.882189: Step 110: Train accuracy = 89.0%
# INFO:tensorflow:2019-08-26 08:24:34.883690: Step 110: Cross entropy = 0.496139
# INFO:tensorflow:2019-08-26 08:24:35.038542: Step 110: Validation accuracy = 80.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:36.523399: Step 120: Train accuracy = 84.0%
# INFO:tensorflow:2019-08-26 08:24:36.524900: Step 120: Cross entropy = 0.574096
# INFO:tensorflow:2019-08-26 08:24:36.681102: Step 120: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:38.162416: Step 130: Train accuracy = 91.0%
# INFO:tensorflow:2019-08-26 08:24:38.162922: Step 130: Cross entropy = 0.449759
# INFO:tensorflow:2019-08-26 08:24:38.323647: Step 130: Validation accuracy = 77.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:39.808388: Step 140: Train accuracy = 90.0%
# INFO:tensorflow:2019-08-26 08:24:39.809896: Step 140: Cross entropy = 0.497214
# INFO:tensorflow:2019-08-26 08:24:39.960562: Step 140: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:41.611002: Step 150: Train accuracy = 83.0%
# INFO:tensorflow:2019-08-26 08:24:41.612003: Step 150: Cross entropy = 0.576104
# INFO:tensorflow:2019-08-26 08:24:41.768203: Step 150: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:43.238722: Step 160: Train accuracy = 88.0%
# INFO:tensorflow:2019-08-26 08:24:43.239723: Step 160: Cross entropy = 0.581418
# INFO:tensorflow:2019-08-26 08:24:43.400361: Step 160: Validation accuracy = 77.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:44.873840: Step 170: Train accuracy = 86.0%
# INFO:tensorflow:2019-08-26 08:24:44.875343: Step 170: Cross entropy = 0.640971
# INFO:tensorflow:2019-08-26 08:24:45.042031: Step 170: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:46.520505: Step 180: Train accuracy = 89.0%
# INFO:tensorflow:2019-08-26 08:24:46.522007: Step 180: Cross entropy = 0.473842
# INFO:tensorflow:2019-08-26 08:24:46.691119: Step 180: Validation accuracy = 79.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:48.173187: Step 190: Train accuracy = 85.0%
# INFO:tensorflow:2019-08-26 08:24:48.174190: Step 190: Cross entropy = 0.435915
# INFO:tensorflow:2019-08-26 08:24:48.347304: Step 190: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:49.832031: Step 200: Train accuracy = 87.0%
# INFO:tensorflow:2019-08-26 08:24:49.832925: Step 200: Cross entropy = 0.564395
# INFO:tensorflow:2019-08-26 08:24:49.987634: Step 200: Validation accuracy = 88.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:51.475412: Step 210: Train accuracy = 96.0%
# INFO:tensorflow:2019-08-26 08:24:51.476913: Step 210: Cross entropy = 0.337666
# INFO:tensorflow:2019-08-26 08:24:51.648312: Step 210: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:53.195977: Step 220: Train accuracy = 91.0%
# INFO:tensorflow:2019-08-26 08:24:53.196980: Step 220: Cross entropy = 0.402581
# INFO:tensorflow:2019-08-26 08:24:53.370569: Step 220: Validation accuracy = 77.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:54.873036: Step 230: Train accuracy = 87.0%
# INFO:tensorflow:2019-08-26 08:24:54.874303: Step 230: Cross entropy = 0.430762
# INFO:tensorflow:2019-08-26 08:24:55.033500: Step 230: Validation accuracy = 80.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:56.584852: Step 240: Train accuracy = 90.0%
# INFO:tensorflow:2019-08-26 08:24:56.585852: Step 240: Cross entropy = 0.565200
# INFO:tensorflow:2019-08-26 08:24:56.809594: Step 240: Validation accuracy = 79.0% (N=100)
# INFO:tensorflow:2019-08-26 08:24:58.388224: Step 250: Train accuracy = 88.0%
# INFO:tensorflow:2019-08-26 08:24:58.389227: Step 250: Cross entropy = 0.368544
# INFO:tensorflow:2019-08-26 08:24:58.566953: Step 250: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:00.046905: Step 260: Train accuracy = 87.0%
# INFO:tensorflow:2019-08-26 08:25:00.047406: Step 260: Cross entropy = 0.386950
# INFO:tensorflow:2019-08-26 08:25:00.217126: Step 260: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:01.736579: Step 270: Train accuracy = 89.0%
# INFO:tensorflow:2019-08-26 08:25:01.738083: Step 270: Cross entropy = 0.367999
# INFO:tensorflow:2019-08-26 08:25:01.909194: Step 270: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:03.480877: Step 280: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:03.482378: Step 280: Cross entropy = 0.412557
# INFO:tensorflow:2019-08-26 08:25:03.649990: Step 280: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:05.219120: Step 290: Train accuracy = 87.0%
# INFO:tensorflow:2019-08-26 08:25:05.220121: Step 290: Cross entropy = 0.432272
# INFO:tensorflow:2019-08-26 08:25:05.390240: Step 290: Validation accuracy = 83.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:06.962419: Step 300: Train accuracy = 90.0%
# INFO:tensorflow:2019-08-26 08:25:06.963917: Step 300: Cross entropy = 0.370486
# INFO:tensorflow:2019-08-26 08:25:07.131528: Step 300: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:08.681710: Step 310: Train accuracy = 88.0%
# INFO:tensorflow:2019-08-26 08:25:08.682713: Step 310: Cross entropy = 0.387521
# INFO:tensorflow:2019-08-26 08:25:08.840910: Step 310: Validation accuracy = 81.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:10.319632: Step 320: Train accuracy = 86.0%
# INFO:tensorflow:2019-08-26 08:25:10.320133: Step 320: Cross entropy = 0.475733
# INFO:tensorflow:2019-08-26 08:25:10.476324: Step 320: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:11.960808: Step 330: Train accuracy = 89.0%
# INFO:tensorflow:2019-08-26 08:25:11.961811: Step 330: Cross entropy = 0.337519
# INFO:tensorflow:2019-08-26 08:25:12.112984: Step 330: Validation accuracy = 78.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:13.801320: Step 340: Train accuracy = 93.0%
# INFO:tensorflow:2019-08-26 08:25:13.802821: Step 340: Cross entropy = 0.292709
# INFO:tensorflow:2019-08-26 08:25:13.961543: Step 340: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:15.439413: Step 350: Train accuracy = 94.0%
# INFO:tensorflow:2019-08-26 08:25:15.439914: Step 350: Cross entropy = 0.335489
# INFO:tensorflow:2019-08-26 08:25:15.592075: Step 350: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:17.102205: Step 360: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:17.103101: Step 360: Cross entropy = 0.372992
# INFO:tensorflow:2019-08-26 08:25:17.253703: Step 360: Validation accuracy = 81.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:18.742250: Step 370: Train accuracy = 93.0%
# INFO:tensorflow:2019-08-26 08:25:18.743750: Step 370: Cross entropy = 0.316751
# INFO:tensorflow:2019-08-26 08:25:18.899415: Step 370: Validation accuracy = 79.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:20.384735: Step 380: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:20.386238: Step 380: Cross entropy = 0.358050
# INFO:tensorflow:2019-08-26 08:25:20.538438: Step 380: Validation accuracy = 73.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:22.031770: Step 390: Train accuracy = 94.0%
# INFO:tensorflow:2019-08-26 08:25:22.032264: Step 390: Cross entropy = 0.243926
# INFO:tensorflow:2019-08-26 08:25:22.193479: Step 390: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:23.678129: Step 400: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:23.679129: Step 400: Cross entropy = 0.332264
# INFO:tensorflow:2019-08-26 08:25:23.833797: Step 400: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:25.318970: Step 410: Train accuracy = 91.0%
# INFO:tensorflow:2019-08-26 08:25:25.320390: Step 410: Cross entropy = 0.333136
# INFO:tensorflow:2019-08-26 08:25:25.475983: Step 410: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:26.976550: Step 420: Train accuracy = 89.0%
# INFO:tensorflow:2019-08-26 08:25:26.977548: Step 420: Cross entropy = 0.379958
# INFO:tensorflow:2019-08-26 08:25:27.139755: Step 420: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:28.701674: Step 430: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:28.703179: Step 430: Cross entropy = 0.329504
# INFO:tensorflow:2019-08-26 08:25:28.884404: Step 430: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:30.473185: Step 440: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:30.474686: Step 440: Cross entropy = 0.294649
# INFO:tensorflow:2019-08-26 08:25:30.625846: Step 440: Validation accuracy = 81.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:32.109415: Step 450: Train accuracy = 90.0%
# INFO:tensorflow:2019-08-26 08:25:32.110418: Step 450: Cross entropy = 0.391413
# INFO:tensorflow:2019-08-26 08:25:32.265548: Step 450: Validation accuracy = 85.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:33.751100: Step 460: Train accuracy = 95.0%
# INFO:tensorflow:2019-08-26 08:25:33.752601: Step 460: Cross entropy = 0.278536
# INFO:tensorflow:2019-08-26 08:25:33.913277: Step 460: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:35.397671: Step 470: Train accuracy = 86.0%
# INFO:tensorflow:2019-08-26 08:25:35.399172: Step 470: Cross entropy = 0.432778
# INFO:tensorflow:2019-08-26 08:25:35.559352: Step 470: Validation accuracy = 86.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:37.052903: Step 480: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:37.054403: Step 480: Cross entropy = 0.376942
# INFO:tensorflow:2019-08-26 08:25:37.205618: Step 480: Validation accuracy = 88.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:38.687683: Step 490: Train accuracy = 93.0%
# INFO:tensorflow:2019-08-26 08:25:38.689509: Step 490: Cross entropy = 0.315935
# INFO:tensorflow:2019-08-26 08:25:38.850203: Step 490: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:2019-08-26 08:25:40.189526: Step 499: Train accuracy = 92.0%
# INFO:tensorflow:2019-08-26 08:25:40.191026: Step 499: Cross entropy = 0.269486
# INFO:tensorflow:2019-08-26 08:25:40.365644: Step 499: Validation accuracy = 90.0% (N=100)
# running testing . . .
# INFO:tensorflow:Final test accuracy = 87.5% (N=352)
# writing trained graph and labbels with weights
# WARNING:tensorflow:From <ipython-input-24-7db352fc43df>:2: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From C:\Users\Michael\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# done !!
